# %% [markdown]
# # Synaptipy — Optogenetic Analysis Example
#
# This notebook demonstrates Synaptipy’s optogenetic synchronization analysis:
#
# 1. Extract TTL/digital stimulus epochs from an auxiliary channel
# 2. Correlate action-potential times with light stimuli
# 3. Compute optical latency, response probability, and jitter
#
# Because the sample ABF files in `examples/data/` may not contain a TTL
# channel, this notebook generates **synthetic data** to illustrate the API.
# Replace the synthetic section with Neo file loading when applying to
# real recordings. Review imported TTL evidence in Protocol Map and assign
# the `optogenetic` protocol before treating latency metrics as ready.
#
# **Requirements:** `pip install synaptipy matplotlib`

# %%
import numpy as np
import matplotlib.pyplot as plt

from synaptipy.core.analysis.evoked_responses import (
    extract_ttl_epochs,
    calculate_optogenetic_sync,
)
from synaptipy.core.analysis.single_spike import detect_spikes_threshold

print("Imports OK")

# %%
# ---------------------------------------------------------------------------
# Publication-quality figure settings
# ---------------------------------------------------------------------------
import matplotlib
import matplotlib.pyplot as plt

matplotlib.rcParams.update({
    "font.family": "sans-serif",
    "font.sans-serif": ["Arial", "Helvetica", "DejaVu Sans"],
    "font.size": 8,
    "axes.titlesize": 8,
    "axes.labelsize": 8,
    "xtick.labelsize": 7,
    "ytick.labelsize": 7,
    "legend.fontsize": 7,
    "axes.spines.top": False,
    "axes.spines.right": False,
    "axes.linewidth": 0.8,
    "xtick.major.width": 0.8,
    "ytick.major.width": 0.8,
    "lines.linewidth": 0.8,
    "figure.dpi": 150,
    "savefig.dpi": 300,
    "pdf.fonttype": 42,
    "ps.fonttype": 42,
})

# %% [markdown]
# ## 1. Create Synthetic Optogenetics Data
#
# We simulate:
# - A voltage trace with spikes that reliably follow light pulses
#   (latency ~ 5 ms ± 1 ms jitter)
# - A TTL channel with 10-ms square pulses at 2 Hz

# %%
np.random.seed(42)
fs = 20_000  # Hz
duration = 5.0  # seconds
n_samples = int(fs * duration)
time = np.arange(n_samples) / fs

# --- TTL channel: 2 Hz, 10 ms pulses ---
ttl = np.zeros(n_samples)
stim_interval = 0.5  # seconds (2 Hz)
pulse_width = 0.010  # 10 ms
stim_onsets = np.arange(0.1, duration - 0.1, stim_interval)
for onset in stim_onsets:
    i0 = int(onset * fs)
    i1 = int((onset + pulse_width) * fs)
    ttl[i0:i1] = 5.0  # 5 V TTL

# --- Voltage trace: resting at -70 mV with evoked spikes ---
voltage = -70.0 + np.random.normal(0, 0.5, n_samples)
response_probability = 0.8  # 80 % response rate
latency_mean_ms = 5.0
latency_std_ms = 1.0

for onset in stim_onsets:
    if np.random.rand() < response_probability:
        latency_s = (latency_mean_ms + np.random.normal(0, latency_std_ms)) / 1000.0
        spike_time = onset + max(latency_s, 0.001)
        idx = int(spike_time * fs)
        if idx + 20 < n_samples:
            # Simple triangular spike waveform
            voltage[idx:idx + 5] = np.linspace(-70, 30, 5)
            voltage[idx + 5:idx + 10] = np.linspace(30, -75, 5)
            voltage[idx + 10:idx + 20] = np.linspace(-75, -70, 10)

print(f"Created {len(stim_onsets)} stimuli over {duration} s")
print(f"Expected response rate: {response_probability * 100:.0f}%")

# %%
# ---------------------------------------------------------------------------
# Publication-quality raw-data overview with L-shaped scale bars
# Voltage trace (top): scale bar 500 ms / 20 mV
# TTL channel (bottom): minimal axes, label only
# ---------------------------------------------------------------------------
WINDOW = (0.0, 2.0)   # show first 2 s for clarity
mask = (time >= WINDOW[0]) & (time <= WINDOW[1])
t_win, v_win, ttl_win = time[mask], voltage[mask], ttl[mask]

fig, axes = plt.subplots(
    2, 1, figsize=(3.5, 3.0),
    gridspec_kw={"height_ratios": [4, 1], "hspace": 0.1},
    sharex=False,
)

# -- Voltage panel -----------------------------------------------------------
ax_v = axes[0]
ax_v.plot(t_win, v_win, color="k", linewidth=0.5)
for spine in ax_v.spines.values():
    spine.set_visible(False)
ax_v.set_xticks([])
ax_v.set_yticks([])
ax_v.set_title("Light-evoked spikes", pad=4)

# L-shaped scale bar
sb_x0 = WINDOW[1] - 0.60
sb_y0 = v_win.min() + 0.08 * (v_win.max() - v_win.min())
sb_dx, sb_dy = 0.500, 20.0       # 500 ms, 20 mV
ax_v.plot([sb_x0, sb_x0 + sb_dx], [sb_y0, sb_y0], color="k",
          linewidth=1.5, solid_capstyle="butt", clip_on=False)
ax_v.plot([sb_x0, sb_x0], [sb_y0, sb_y0 + sb_dy], color="k",
          linewidth=1.5, solid_capstyle="butt", clip_on=False)
ax_v.text(sb_x0 + sb_dx / 2, sb_y0 - 2.5, "500 ms",
          ha="center", va="top", fontsize=7)
ax_v.text(sb_x0 - 0.02, sb_y0 + sb_dy / 2, "20 mV",
          ha="right", va="center", fontsize=7, rotation=90)

# -- TTL panel ---------------------------------------------------------------
ax_t = axes[1]
ax_t.fill_between(t_win, 0, ttl_win, color="royalblue", alpha=0.7,
                  step="post", linewidth=0)
ax_t.set_ylim(-0.5, 6.5)
ax_t.set_xlim(WINDOW)
ax_t.spines["left"].set_visible(False)
ax_t.spines["top"].set_visible(False)
ax_t.spines["right"].set_visible(False)
ax_t.set_yticks([])
ax_t.set_xlabel("Time (s)", labelpad=2)
ax_t.set_ylabel("TTL", rotation=0, labelpad=18, va="center")

plt.savefig("fig_opto_raw.pdf", bbox_inches="tight")
plt.savefig("fig_opto_raw.png", bbox_inches="tight")
plt.close("all")

# %% [markdown]
# ## 2. Extract TTL Epochs
#
# `extract_ttl_epochs` detects rising and falling edges of the digital signal
# and returns stimulus onset / offset times in seconds.

# %%
onsets, offsets = extract_ttl_epochs(ttl, time, threshold=2.5)

print(f"Detected {len(onsets)} stimulus epochs")
print(f"First onset:  {onsets[0]:.4f} s")
print(f"First offset: {offsets[0]:.4f} s")
print(f"Pulse width:  {(offsets[0] - onsets[0]) * 1000:.1f} ms")

# %% [markdown]
# ## 3. Detect Spikes
#
# Run threshold-based spike detection on the voltage trace.

# %%
refractory = int(0.002 * fs)  # 2 ms
spike_result = detect_spikes_threshold(
    voltage, time,
    threshold=-20.0,
    refractory_samples=refractory,
)

ap_times = spike_result.spike_times if spike_result.spike_times is not None else np.array([])
print(f"Detected {len(ap_times)} action potentials")

# %% [markdown]
# ## 4. Optogenetic Synchronization
#
# `calculate_optogenetic_sync` correlates detected spikes with TTL stimuli
# and computes:
# - **Optical latency** — mean time from stimulus onset to first spike (successful trials only)
# - **Response probability** — fraction of stimuli that evoke ≥1 spike
# - **Response Probability (%)** — same as above expressed as a percentage
# - **Success Count** — number of stimulus trials with at least one evoked spike
# - **Failure Count** — number of stimulus trials with no evoked spike
# - **Jitter** — standard deviation of spike latencies across successful trials only
#
# > **Note:** Latency and jitter are restricted to *successful* trials to prevent
# > NaN propagation. Trials with no detectable response are counted separately as
# > `Failure Count`.

# %%
opto_result = calculate_optogenetic_sync(
    ttl_data=ttl,
    action_potential_times=ap_times,
    time=time,
    ttl_threshold=2.5,
    response_window_ms=20.0,
)

# --- Core metrics ---
print(f"Stimulus count:           {opto_result.stimulus_count}")
print(f"Success count:            {opto_result.success_count}")
print(f"Failure count:            {opto_result.failure_count}")
resp_pct = (opto_result.response_probability * 100.0
            if opto_result.response_probability is not None else float('nan'))
print(f"Response Probability (%): {resp_pct:.1f} %")

# Latency and jitter are computed only over successful trials (NaN when 0 successes).
print(f"Optical latency:          {opto_result.optical_latency_ms:.2f} ms")
print(f"Spike jitter (SD):        {opto_result.spike_jitter_ms:.2f} ms")

# %% [markdown]
# ## 5. Peri-Stimulus Time Histogram (PSTH)
#
# Plot the distribution of spike latencies relative to stimulus onset.

# %%
# ---------------------------------------------------------------------------
# Publication-quality Peri-Stimulus Time Histogram (PSTH)
# ---------------------------------------------------------------------------
latencies = []
stim_onset_times = opto_result.stimulus_onsets

for onset, spk_list in zip(stim_onset_times, opto_result.responding_spikes):
    if spk_list is not None and len(spk_list) > 0:
        latencies.append((spk_list[0] - onset) * 1000.0)

fig, ax = plt.subplots(figsize=(3.0, 2.5))
if latencies:
    lat_arr = np.array(latencies)
    bins = np.linspace(lat_arr.min() - 0.5, lat_arr.max() + 0.5, 20)
    ax.hist(lat_arr, bins=bins, color="#4393c3", edgecolor="white",
            linewidth=0.5)
    med = np.median(lat_arr)
    ax.axvline(med, color="#d6604d", linewidth=1.2, linestyle="--",
               label=f"Median {med:.1f} ms")
    ax.legend(frameon=False)

ax.set_xlabel("Latency from stimulus onset (ms)")
ax.set_ylabel("Count")
ax.set_title("Peri-Stimulus Time Histogram")

plt.tight_layout()
plt.savefig("fig_psth.pdf", bbox_inches="tight")
plt.savefig("fig_psth.png", bbox_inches="tight")
plt.close("all")

# %% [markdown]
# ## 6. Raster Plot
#
# Each row = one stimulus trial; dots show spike times relative to
# stimulus onset.

# %%
# ---------------------------------------------------------------------------
# Publication-quality raster plot
# Each row = one stimulus trial; ticks = spike latencies relative to onset
# ---------------------------------------------------------------------------
n_trials = len(opto_result.stimulus_onsets)
fig_h = max(2.0, 0.18 * n_trials + 0.8)
fig, ax = plt.subplots(figsize=(3.0, fig_h))

for trial_idx, (onset, spk_list) in enumerate(
    zip(opto_result.stimulus_onsets, opto_result.responding_spikes)
):
    if spk_list is not None and len(spk_list) > 0:
        lat_ms = [(s - onset) * 1000.0 for s in spk_list]
        ax.scatter(lat_ms, [trial_idx] * len(lat_ms),
                   marker="|", color="k", s=30, linewidths=0.8)

ax.axvline(0, color="royalblue", linewidth=1.0, linestyle="-",
           label="Stimulus onset", zorder=0)
ax.set_xlabel("Latency (ms)")
ax.set_ylabel("Trial")
ax.set_xlim(-5, 30)
ax.set_ylim(-1, n_trials)
ax.legend(frameon=False, loc="upper right")
ax.set_title("Raster — spike latencies per trial")

plt.tight_layout()
plt.savefig("fig_raster.pdf", bbox_inches="tight")
plt.savefig("fig_raster.png", bbox_inches="tight")
plt.close("all")

# %% [markdown]
# ---
#
# ### Applying to Real Data
#
# Replace the synthetic-data section with:
#
# ```python
# from synaptipy.infrastructure.file_readers.neo_adapter import NeoAdapter
#
# adapter = NeoAdapter()
# recording = adapter.read_recording("path/to/your/file.abf")
#
# # Pick the voltage and TTL channels by name or index
# v_ch = recording.channels["Channel 0"]
# ttl_ch = recording.channels["Channel 1"]
#
# voltage = v_ch.data_trials[0]
# ttl = ttl_ch.data_trials[0]
# ```
